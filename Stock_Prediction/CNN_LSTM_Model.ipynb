# %%
import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler,MinMaxScaler
from sklearn.model_selection import train_test_split

import tensorflow as tf
from keras.callbacks import ModelCheckpoint
from keras.models import Sequential
from keras.layers import LSTM,Conv1D,Conv2D,MaxPooling2D,MaxPooling1D,Flatten
from keras.layers import Dense, Dropout
from tensorflow.compat.v1.keras.layers import CuDNNLSTM,Bidirectional

# %%
tf.keras.utils.set_random_seed(42)  # sets seeds for base-python, numpy and tf
tf.config.experimental.enable_op_determinism()

# %%
df_2022 = pd.read_csv('../Tweet_Sentiment/2022_final.csv').drop(['fark', 'tweet_count'], axis= 1).set_index('Unnamed: 0').sort_index()
df_2021 = pd.read_csv('../Tweet_Sentiment/2021_final.csv').drop(['fark', 'tweet_count'], axis= 1).set_index('Unnamed: 0').sort_index()

# %%
df = pd.concat([df_2022, df_2021]).sort_index()
df
# Out:
#               şimdi   açılış  avg_polar
# Unnamed: 0
# 2021-01-04  1495.43  1482.17   0.598575
# 2021-01-05  1489.56  1492.19   0.543668
# 2021-01-06  1505.42  1501.61   0.557471
# 2021-01-07  1522.24  1511.60   0.535849
# 2021-01-08  1540.61  1526.51   0.562334
# ...             ...      ...        ...
# 2022-10-12  3517.75  3576.84   0.488859
# 2022-10-13  3553.43  3529.78   0.497640
# 2022-10-14  3626.96  3584.94   0.479313
# 2022-10-17  3847.62  3641.40   0.529757
# 2022-10-18  3841.56  3847.62   0.496745
#
# [404 rows x 3 columns]

# %%
scaler = MinMaxScaler()
scaler = scaler.fit(df)
df_for_training_scaled = scaler.transform(df)

scaler_for_inference = MinMaxScaler()
scaler_for_inference.fit_transform(df.loc[:,['şimdi']])
# Out:
# array([[5.94174618e-02],
#        [5.70701941e-02],
#        [6.34122154e-02],
#        [7.01381169e-02],
#        [7.74838250e-02],
#        [7.57163765e-02],
#        [8.10507122e-02],
#        [8.49494958e-02],
#        [7.98790777e-02],
#        [7.10378362e-02],
#        [8.39458089e-02],
#        [8.72407809e-02],
#        [8.89762394e-02],
#        [8.18664577e-02],
#        [7.82195955e-02],
#        [7.73238750e-02],
#        [7.56843865e-02],
#        [4.80490087e-02],
#        [6.05731012e-02],
#        [5.06282040e-02],
#        [5.82258335e-02],
#        [6.58154656e-02],
#        [7.46607059e-02],
#        [7.52005374e-02],
#        [7.21095018e-02],
#        [7.52045362e-02],
#        [7.88593959e-02],
#        [8.00830141e-02],
#        [7.94752037e-02],
#        [7.66160958e-02],
#        [8.62330953e-02],
#        [7.83675493e-02],
#        [7.74758275e-02],
#        [7.98031014e-02],
#        [8.53733635e-02],
#        [8.14825774e-02],
#        [6.83866634e-02],
#        [5.44550100e-02],
#        [5.65303625e-02],
#        [4.98044610e-02],
#        [2.97147290e-02],
#        [2.77553403e-02],
#        [2.92548725e-02],
#        [3.23459081e-02],
#        [3.77842113e-02],
#        [4.56097698e-02],
#        [3.91997697e-02],
#        [3.77842113e-02],
#        [4.29505994e-02],
#        [4.50779357e-02],
#        [4.11791521e-02],
#        [4.19869001e-02],
#        [4.21228577e-02],
#        [2.13453403e-02],
#        [3.20779917e-02],
#        [2.72674925e-02],
#        [3.00786155e-02],
#        [2.94508113e-02],
#        [3.40693704e-02],
#        [3.35455338e-02],
#        [3.25058582e-02],
#        [3.44252593e-02],
#        [4.00834939e-02],
#        [4.02874303e-02],
#        [4.09192332e-02],
#        [4.39222962e-02],
#        [4.55937747e-02],
#        [4.29505994e-02],
#        [3.82760579e-02],
#        [3.37774614e-02],
#        [2.69156023e-02],
#        [1.76824831e-02],
#        [2.06655523e-02],
#        [2.51961388e-02],
#        [2.21970745e-02],
#        [2.55720215e-02],
#        [1.80023833e-02],
#        [1.05607051e-02],
#        [9.92890218e-03],
#        [3.79881477e-03],
#        [1.03727637e-02],
#        [1.19282784e-02],
#        [1.83142859e-02],
#        [1.42915410e-02],
#        [1.74905430e-02],
#        [1.04527387e-02],
#        [1.25720775e-02],
#        [4.04673742e-03],
#        [0.00000000e+00],
#        [8.16145363e-03],
#        [6.57394893e-03],
#        [1.89940738e-03],
#        [9.07716792e-04],
#        [5.08241429e-03],
#        [5.56226457e-03],
#        [1.79144107e-02],
#        [1.84222523e-02],
#        [2.11174114e-02],
#        [2.47802686e-02],
#        [2.67756460e-02],
#        [3.39654028e-02],
#        [3.51570310e-02],
#        [3.42972992e-02],
#        [3.62366942e-02],
#        [2.56040115e-02],
#        [3.90358208e-02],
#        [4.03074241e-02],
#        [4.33504747e-02],
#        [4.59256712e-02],
#        [4.10871808e-02],
#        [3.71963947e-02],
#        [3.91037996e-02],
#        [4.49819656e-02],
#        [4.76051472e-02],
#        [4.25707179e-02],
#        [4.06593143e-02],
#        [4.45421029e-02],
#        [5.00763762e-02],
#        [5.09001192e-02],
#        [5.28954966e-02],
#        [4.87168004e-02],
#        [5.11360456e-02],
#        [4.31465383e-02],
#        [3.47931445e-02],
#        [4.23187965e-02],
#        [3.67405370e-02],
#        [3.65645918e-02],
#        [3.50250722e-02],
#        [3.08423772e-02],
#        [2.84671183e-02],
#        [2.90269436e-02],
#        [1.80223770e-02],
#        [1.55031630e-02],
#        [2.42404370e-02],
#        [2.18411856e-02],
#        [1.51312790e-02],
#        [1.79543982e-02],
#        [1.47673926e-02],
#        [1.80263758e-02],
#        [2.38125705e-02],
#        [2.18411856e-02],
#        [1.90060701e-02],
#        [1.79184095e-02],
#        [9.93689969e-03],
#        [2.00257520e-02],
#        [2.04576172e-02],
#        [2.77753341e-02],
#        [2.79832692e-02],
#        [2.66716784e-02],
#        [2.59559018e-02],
#        [2.50801750e-02],
#        [2.83351594e-02],
#        [3.31936436e-02],
#        [3.43732755e-02],
#        [4.34184534e-02],
#        [5.32193955e-02],
#        [5.84177737e-02],
#        [6.49237438e-02],
#        [6.89424899e-02],
#        [7.00581419e-02],
#        [7.57683603e-02],
#        [7.44607682e-02],
#        [8.00510241e-02],
#        [9.15034509e-02],
#        [9.46704628e-02],
#        [1.04647350e-01],
#        [1.07486464e-01],
#        [1.10865410e-01],
#        [1.11253289e-01],
#        [1.16627612e-01],
#        [1.42215629e-01],
#        [1.35461736e-01],
#        [1.44035061e-01],
#        [1.55967338e-01],
#        [1.56147282e-01],
#        [1.63405018e-01],
#        [1.75033390e-01],
#        [1.86125929e-01],
#        [1.88897064e-01],
#        [1.71774406e-01],
#        [1.84722367e-01],
#        [1.85066259e-01],
#        [2.04160302e-01],
#        [2.13221475e-01],
#        [2.25357688e-01],
#        [2.32147570e-01],
#        [2.53600877e-01],
#        [2.63001943e-01],
#        [2.73754589e-01],
#        [2.75370085e-01],
#        [3.01773847e-01],
#        [3.24258831e-01],
#        [3.26066267e-01],
#        [3.72567759e-01],
#        [2.94959972e-01],
#        [2.83719480e-01],
#        [2.18003983e-01],
#        [1.82866946e-01],
#        [1.83326802e-01],
#        [2.17708075e-01],
#        [2.20047345e-01],
#        [2.01393165e-01],
#        [2.19379554e-01],
#        [2.06659522e-01],
#        [2.04260271e-01],
#        [2.31855661e-01],
#        [2.46623054e-01],
#        [2.63297851e-01],
#        [2.64201569e-01],
#        [2.74506354e-01],
#        [2.79240877e-01],
#        [2.79588768e-01],
#        [2.86858500e-01],
#        [2.89433697e-01],
#        [2.90345412e-01],
#        [2.95475812e-01],
#        [2.53117027e-01],
#        [2.78009261e-01],
#        [2.66864738e-01],
#        [2.65645119e-01],
#        [2.25309703e-01],
#        [2.39217364e-01],
#        [2.41656603e-01],
#        [2.60258799e-01],
#        [2.54456610e-01],
#        [2.62462112e-01],
#        [2.67352586e-01],
#        [2.62078232e-01],
#        [2.44347763e-01],
#        [2.38713521e-01],
#        [2.60214813e-01],
#        [2.64037620e-01],
#        [2.78317165e-01],
#        [2.76645687e-01],
#        [2.81596142e-01],
#        [2.61958269e-01],
#        [2.76441750e-01],
#        [2.77749342e-01],
#        [2.65177265e-01],
#        [2.74154464e-01],
#        [2.76401763e-01],
#        [2.68164333e-01],
#        [2.67592511e-01],
#        [2.01753053e-01],
#        [2.42148450e-01],
#        [2.39665224e-01],
#        [2.49150265e-01],
#        [2.55620246e-01],
#        [2.70495605e-01],
#        [2.57483665e-01],
#        [2.60114844e-01],
#        [2.65721095e-01],
#        [2.78257184e-01],
#        [2.77981270e-01],
#        [2.82715793e-01],
#        [2.96563472e-01],
#        [2.92924608e-01],
#        [2.96691432e-01],
#        [3.14601844e-01],
#        [3.18868513e-01],
#        [3.31172674e-01],
#        [3.36682955e-01],
#        [3.34399667e-01],
#        [3.31640528e-01],
#        [3.31364614e-01],
#        [3.30152992e-01],
#        [3.43756748e-01],
#        [3.53213797e-01],
#        [3.54473404e-01],
#        [3.61823111e-01],
#        [3.85703660e-01],
#        [3.91657803e-01],
#        [3.87703037e-01],
#        [3.99219444e-01],
#        [4.18489431e-01],
#        [4.40770480e-01],
#        [4.46628652e-01],
#        [4.45297067e-01],
#        [4.51287198e-01],
#        [4.58868833e-01],
#        [4.65242844e-01],
#        [4.68813730e-01],
#        [4.71488895e-01],
#        [4.83837043e-01],
#        [4.50123561e-01],
#        [4.54162301e-01],
#        [4.28450323e-01],
#        [4.41698190e-01],
#        [4.32497061e-01],
#        [4.33348795e-01],
#        [4.47628340e-01],
#        [4.44613281e-01],
#        [4.47408409e-01],
#        [4.57189357e-01],
#        [4.42701877e-01],
#        [4.17525732e-01],
#        [4.28822207e-01],
#        [4.17449756e-01],
#        [4.19065252e-01],
#        [4.18577404e-01],
#        [4.10076056e-01],
#        [4.13494990e-01],
#        [4.11135726e-01],
#        [4.28370348e-01],
#        [4.41462264e-01],
#        [4.36663761e-01],
#        [4.71976743e-01],
#        [4.79950256e-01],
#        [4.88615552e-01],
#        [5.01731460e-01],
#        [5.01607498e-01],
#        [5.20349651e-01],
#        [5.20377642e-01],
#        [4.77259095e-01],
#        [4.89739201e-01],
#        [4.78354753e-01],
#        [4.65174865e-01],
#        [4.64683019e-01],
#        [4.73560249e-01],
#        [4.55265957e-01],
#        [4.74447972e-01],
#        [4.76795240e-01],
#        [4.91454666e-01],
#        [4.90830861e-01],
#        [4.78398740e-01],
#        [4.82745383e-01],
#        [4.72820480e-01],
#        [4.57217348e-01],
#        [4.21916362e-01],
#        [4.23275938e-01],
#        [4.38635146e-01],
#        [4.23523861e-01],
#        [4.09636194e-01],
#        [4.24391590e-01],
#        [4.31353418e-01],
#        [4.34736362e-01],
#        [4.24363599e-01],
#        [4.14110797e-01],
#        [4.41634210e-01],
#        [4.61903886e-01],
#        [4.71196987e-01],
#        [4.65666712e-01],
#        [4.67742064e-01],
#        [4.80510081e-01],
#        [4.75963499e-01],
#        [4.78762626e-01],
#        [4.78446725e-01],
#        [4.98060605e-01],
#        [5.23628628e-01],
#        [5.20137717e-01],
#        [5.34881117e-01],
#        [5.50560225e-01],
#        [5.61284879e-01],
#        [5.79107319e-01],
#        [5.75148554e-01],
#        [5.92911012e-01],
#        [6.08450164e-01],
#        [6.06774686e-01],
#        [6.03947568e-01],
#        [6.26388567e-01],
#        [6.53060245e-01],
#        [6.69059254e-01],
#        [6.69135230e-01],
#        [6.86045954e-01],
#        [7.09650589e-01],
#        [6.85170227e-01],
#        [7.15748686e-01],
#        [7.19479522e-01],
#        [7.27021169e-01],
#        [7.29520390e-01],
#        [7.18135942e-01],
#        [7.50125961e-01],
#        [8.04361039e-01],
#        [8.17560921e-01],
#        [8.22131495e-01],
#        [8.35967178e-01],
#        [8.69544702e-01],
#        [9.20660754e-01],
#        [8.31756492e-01],
#        [8.39785987e-01],
#        [8.06260447e-01],
#        [8.11942674e-01],
#        [7.40848855e-01],
#        [7.72023129e-01],
#        [7.59331089e-01],
#        [7.79128912e-01],
#        [7.73666616e-01],
#        [7.65085293e-01],
#        [7.67280608e-01],
#        [7.40297027e-01],
#        [7.19795424e-01],
#        [7.33031294e-01],
#        [8.17860827e-01],
#        [8.44212606e-01],
#        [8.54765313e-01],
#        [8.82528651e-01],
#        [8.88026936e-01],
#        [8.93797135e-01],
#        [8.89606443e-01],
#        [8.68093155e-01],
#        [8.82360703e-01],
#        [9.11763530e-01],
#        [1.00000000e+00],
#        [9.97576756e-01]])

# %%
#Empty lists to be populated using formatted training data
trainX = []
trainY = []

n_future = 1   # Number of days we want to look into the future based on the past days.
n_past = 5  # Number of past days we want to use to predict the future.

#Reformat input data into a shape: (n_samples x timesteps x n_features)
#In my example, my df_for_training_scaled has a shape (12823, 5)
#12823 refers to the number of data points and 5 refers to the columns (multi-variables).
for i in range(n_past, len(df_for_training_scaled) - n_future +1):
    trainX.append(df_for_training_scaled[i - n_past:i, 0:df.shape[1]])
    trainY.append(df_for_training_scaled[i + n_future - 1:i + n_future,[0]])

trainX, trainY = np.array(trainX), np.array(trainY)

print('TrainX shape = {}.'.format(trainX.shape))
print('TrainY shape = {}.'.format(trainY.shape))
# Out:
# TrainX shape = (399, 5, 3).
# TrainY shape = (399, 1, 1).

# %%
X_train_lstm_without_twitter, X_test_lstm_without_twitter, y_train_lstm_without_twitter, y_test_lstm_without_twitter = train_test_split(trainX[:,:,:-1], trainY, test_size=30, shuffle=False)

X_train_lstm_twitter, X_test_lstm_twitter, y_train_lstm_twitter, y_test_lstm_twitter = train_test_split(trainX, trainY, test_size=30, shuffle=False)

X_train_lstm_without_twitter.shape,X_train_lstm_twitter.shape
# Out:
# ((369, 5, 2), (369, 5, 3))

# %%
def build_model(input_shape):
    tf.keras.utils.set_random_seed(42)  # sets seeds for base-python, numpy and tf
    cnn_lstm_model = Sequential()

    cnn_lstm_model.add(Conv1D(filters=128, kernel_size=2, strides=1, padding='valid', input_shape=input_shape))
    cnn_lstm_model.add(MaxPooling1D(pool_size=2, strides=2))

    cnn_lstm_model.add(Conv1D(filters=64, kernel_size=2, strides=1, padding='valid'))
    cnn_lstm_model.add(MaxPooling1D(pool_size=1, strides=2))
    # cnn_lstm_model.add(MaxPooling1D(pool_size=1, strides=2))

    cnn_lstm_model.add(Bidirectional(CuDNNLSTM(256, return_sequences=True)))
    cnn_lstm_model.add(Dropout(0.2))
    cnn_lstm_model.add(Bidirectional(CuDNNLSTM(256, return_sequences=True)))
    cnn_lstm_model.add(Dropout(0.2))

    cnn_lstm_model.add(Dense(32, activation='relu'))


    cnn_lstm_model.add(Dense(trainY.shape[2], activation='relu'))

    # cnn_lstm_model.build(input_shape=(trainX.shape[0], trainX.shape[1], trainX.shape[2]))

    cnn_lstm_model.compile(optimizer='adam', loss='mse')
    cnn_lstm_model.summary()
    return cnn_lstm_model

# %%
cnn_lstm_model_without_twitter=build_model((X_train_lstm_without_twitter.shape[1],X_train_lstm_without_twitter.shape[2]))
cnn_lstm_model_twitter=build_model((X_train_lstm_twitter.shape[1],X_train_lstm_twitter.shape[2]))

history_without_twitter = cnn_lstm_model_without_twitter.fit(X_train_lstm_without_twitter, y_train_lstm_without_twitter, epochs=60, batch_size=64, verbose=1, )


history_twitter = cnn_lstm_model_twitter.fit(X_train_lstm_twitter, y_train_lstm_twitter, epochs=60, batch_size=64, verbose=1, )
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 4, 128)            640
#
#  max_pooling1d (MaxPooling1D  (None, 2, 128)           0
#  )
#
#  conv1d_1 (Conv1D)           (None, 1, 64)             16448
#
#  max_pooling1d_1 (MaxPooling  (None, 1, 64)            0
#  1D)
#
#  bidirectional (Bidirectiona  (None, 1, 512)           659456
#  l)
#
#  dropout (Dropout)           (None, 1, 512)            0
#
#  bidirectional_1 (Bidirectio  (None, 1, 512)           1576960
#  nal)
#
#  dropout_1 (Dropout)         (None, 1, 512)            0
#
#  dense (Dense)               (None, 1, 32)             16416
#
#  dense_1 (Dense)             (None, 1, 1)              33
#
# =================================================================
# Total params: 2,269,953
# Trainable params: 2,269,953
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_2 (Conv1D)           (None, 4, 128)            896
#
#  max_pooling1d_2 (MaxPooling  (None, 2, 128)           0
#  1D)
#
#  conv1d_3 (Conv1D)           (None, 1, 64)             16448
#
#  max_pooling1d_3 (MaxPooling  (None, 1, 64)            0
#  1D)
#
#  bidirectional_2 (Bidirectio  (None, 1, 512)           659456
#  nal)
#
#  dropout_2 (Dropout)         (None, 1, 512)            0
#
#  bidirectional_3 (Bidirectio  (None, 1, 512)           1576960
#  nal)
#
#  dropout_3 (Dropout)         (None, 1, 512)            0
#
#  dense_2 (Dense)             (None, 1, 32)             16416
#
#  dense_3 (Dense)             (None, 1, 1)              33
#
# =================================================================
# Total params: 2,270,209
# Trainable params: 2,270,209
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/60
# 6/6 [==============================] - 4s 12ms/step - loss: 0.0848
# Epoch 2/60
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0248
# Epoch 3/60
# 6/6 [==============================] - 0s 10ms/step - loss: 0.0121
# Epoch 4/60
# 6/6 [==============================] - 0s 10ms/step - loss: 0.0074
# Epoch 5/60
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0026
# Epoch 6/60
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0017
# Epoch 7/60
# 6/6 [==============================] - 0s 10ms/step - loss: 0.0014
# Epoch 8/60
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0010
# Epoch 9/60
# 6/6 [==============================] - 0s 11ms/step - loss: 8.7584e-04
# Epoch 10/60
# 6/6 [==============================] - 0s 11ms/step - loss: 7.4259e-04
# Epoch 11/60
# 6/6 [==============================] - 0s 12ms/step - loss: 6.8397e-04
# Epoch 12/60
# 6/6 [==============================] - 0s 11ms/step - loss: 6.5058e-04
# Epoch 13/60
# 6/6 [==============================] - 0s 11ms/step - loss: 6.3160e-04
# Epoch 14/60
# 6/6 [==============================] - 0s 10ms/step - loss: 6.8024e-04
# Epoch 15/60
# 6/6 [==============================] - 0s 10ms/step - loss: 6.5847e-04
# Epoch 16/60
# 6/6 [==============================] - 0s 11ms/step - loss: 5.3780e-04
# Epoch 17/60
# 6/6 [==============================] - 0s 11ms/step - loss: 5.9617e-04
# Epoch 18/60
# 6/6 [==============================] - 0s 12ms/step - loss: 6.3122e-04
# Epoch 19/60
# 6/6 [==============================] - 0s 11ms/step - loss: 7.1974e-04
# Epoch 20/60
# 6/6 [==============================] - 0s 11ms/step - loss: 7.9385e-04
# Epoch 21/60
# 6/6 [==============================] - 0s 11ms/step - loss: 7.6415e-04
# Epoch 22/60
# 6/6 [==============================] - 0s 10ms/step - loss: 6.2012e-04
# Epoch 23/60
# 6/6 [==============================] - 0s 10ms/step - loss: 6.0382e-04
# Epoch 24/60
# 6/6 [==============================] - 0s 11ms/step - loss: 6.0512e-04
# Epoch 25/60
# 6/6 [==============================] - 0s 11ms/step - loss: 6.1936e-04
# Epoch 26/60
# 6/6 [==============================] - 0s 11ms/step - loss: 5.3778e-04
# Epoch 27/60
# 6/6 [==============================] - 0s 11ms/step - loss: 4.7751e-04
# Epoch 28/60
# 6/6 [==============================] - 0s 11ms/step - loss: 5.2514e-04
# Epoch 29/60
# 6/6 [==============================] - 0s 11ms/step - loss: 5.5399e-04
# Epoch 30/60
# 6/6 [==============================] - 0s 11ms/step - loss: 6.3130e-04
# Epoch 31/60
# 6/6 [==============================] - 0s 10ms/step - loss: 5.8916e-04
# Epoch 32/60
# 6/6 [==============================] - 0s 11ms/step - loss: 5.6758e-04
# Epoch 33/60
# 6/6 [==============================] - 0s 11ms/step - loss: 5.4637e-04
# Epoch 34/60
# 6/6 [==============================] - 0s 11ms/step - loss: 5.2698e-04
# Epoch 35/60
# 6/6 [==============================] - 0s 11ms/step - loss: 6.2318e-04
# Epoch 36/60
# 6/6 [==============================] - 0s 11ms/step - loss: 5.5178e-04
# Epoch 37/60
# 6/6 [==============================] - 0s 10ms/step - loss: 5.9659e-04
# Epoch 38/60
# 6/6 [==============================] - 0s 11ms/step - loss: 6.4632e-04
# Epoch 39/60
# 6/6 [==============================] - 0s 10ms/step - loss: 6.0268e-04
# Epoch 40/60
# 6/6 [==============================] - 0s 11ms/step - loss: 4.8980e-04
# Epoch 41/60
# 6/6 [==============================] - 0s 11ms/step - loss: 4.7807e-04
# Epoch 42/60
# 6/6 [==============================] - 0s 11ms/step - loss: 4.4183e-04
# Epoch 43/60
# 6/6 [==============================] - 0s 12ms/step - loss: 6.6311e-04
# Epoch 44/60
# 6/6 [==============================] - 0s 11ms/step - loss: 6.7606e-04
# Epoch 45/60
# 6/6 [==============================] - 0s 10ms/step - loss: 4.8535e-04
# Epoch 46/60
# 6/6 [==============================] - 0s 11ms/step - loss: 4.8999e-04
# Epoch 47/60
# 6/6 [==============================] - 0s 11ms/step - loss: 4.9194e-04
# Epoch 48/60
# 6/6 [==============================] - 0s 12ms/step - loss: 4.5457e-04
# Epoch 49/60
# 6/6 [==============================] - 0s 11ms/step - loss: 5.1919e-04
# Epoch 50/60
# 6/6 [==============================] - 0s 11ms/step - loss: 4.1951e-04
# Epoch 51/60
# 6/6 [==============================] - 0s 11ms/step - loss: 4.1745e-04
# Epoch 52/60
# 6/6 [==============================] - 0s 11ms/step - loss: 4.6268e-04
# Epoch 53/60
# 6/6 [==============================] - 0s 11ms/step - loss: 3.9734e-04
# Epoch 54/60
# 6/6 [==============================] - 0s 12ms/step - loss: 4.4903e-04
# Epoch 55/60
# 6/6 [==============================] - 0s 12ms/step - loss: 4.4981e-04
# Epoch 56/60
# 6/6 [==============================] - 0s 11ms/step - loss: 4.0490e-04
# Epoch 57/60
# 6/6 [==============================] - 0s 11ms/step - loss: 4.3084e-04
# Epoch 58/60
# 6/6 [==============================] - 0s 11ms/step - loss: 4.2861e-04
# Epoch 59/60
# 6/6 [==============================] - 0s 12ms/step - loss: 3.5970e-04
# Epoch 60/60
# 6/6 [==============================] - 0s 11ms/step - loss: 3.9977e-04
# Epoch 1/60
# 6/6 [==============================] - 2s 23ms/step - loss: 0.0936
# Epoch 2/60
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0936
# Epoch 3/60
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0936
# Epoch 4/60
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0936
# Epoch 5/60
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0936
# Epoch 6/60
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0828
# Epoch 7/60
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0246
# Epoch 8/60
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0103
# Epoch 9/60
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0057
# Epoch 10/60
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0049
# Epoch 11/60
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0027
# Epoch 12/60
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0020
# Epoch 13/60
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0015
# Epoch 14/60
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0012
# Epoch 15/60
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0010
# Epoch 16/60
# 6/6 [==============================] - 0s 12ms/step - loss: 7.6085e-04
# Epoch 17/60
# 6/6 [==============================] - 0s 11ms/step - loss: 6.3823e-04
# Epoch 18/60
# 6/6 [==============================] - 0s 11ms/step - loss: 7.0011e-04
# Epoch 19/60
# 6/6 [==============================] - 0s 11ms/step - loss: 6.0577e-04
# Epoch 20/60
# 6/6 [==============================] - 0s 12ms/step - loss: 7.3193e-04
# Epoch 21/60
# 6/6 [==============================] - 0s 11ms/step - loss: 6.8417e-04
# Epoch 22/60
# 6/6 [==============================] - 0s 11ms/step - loss: 5.1910e-04
# Epoch 23/60
# 6/6 [==============================] - 0s 11ms/step - loss: 5.3406e-04
# Epoch 24/60
# 6/6 [==============================] - 0s 11ms/step - loss: 5.3583e-04
# Epoch 25/60
# 6/6 [==============================] - 0s 11ms/step - loss: 5.5647e-04
# Epoch 26/60
# 6/6 [==============================] - 0s 11ms/step - loss: 5.2328e-04
# Epoch 27/60
# 6/6 [==============================] - 0s 11ms/step - loss: 4.9349e-04
# Epoch 28/60
# 6/6 [==============================] - 0s 11ms/step - loss: 5.0461e-04
# Epoch 29/60
# 6/6 [==============================] - 0s 11ms/step - loss: 5.3976e-04
# Epoch 30/60
# 6/6 [==============================] - 0s 11ms/step - loss: 6.0339e-04
# Epoch 31/60
# 6/6 [==============================] - 0s 11ms/step - loss: 5.1689e-04
# Epoch 32/60
# 6/6 [==============================] - 0s 12ms/step - loss: 5.8844e-04
# Epoch 33/60
# 6/6 [==============================] - 0s 11ms/step - loss: 5.1179e-04
# Epoch 34/60
# 6/6 [==============================] - 0s 12ms/step - loss: 4.6015e-04
# Epoch 35/60
# 6/6 [==============================] - 0s 11ms/step - loss: 5.0357e-04
# Epoch 36/60
# 6/6 [==============================] - 0s 11ms/step - loss: 4.9627e-04
# Epoch 37/60
# 6/6 [==============================] - 0s 12ms/step - loss: 5.1773e-04
# Epoch 38/60
# 6/6 [==============================] - 0s 14ms/step - loss: 5.4695e-04
# Epoch 39/60
# 6/6 [==============================] - 0s 13ms/step - loss: 5.4011e-04
# Epoch 40/60
# 6/6 [==============================] - 0s 12ms/step - loss: 4.6620e-04
# Epoch 41/60
# 6/6 [==============================] - 0s 11ms/step - loss: 4.6722e-04
# Epoch 42/60
# 6/6 [==============================] - 0s 13ms/step - loss: 4.5640e-04
# Epoch 43/60
# 6/6 [==============================] - 0s 14ms/step - loss: 5.1488e-04
# Epoch 44/60
# 6/6 [==============================] - 0s 12ms/step - loss: 5.2726e-04
# Epoch 45/60
# 6/6 [==============================] - 0s 13ms/step - loss: 4.2289e-04
# Epoch 46/60
# 6/6 [==============================] - 0s 13ms/step - loss: 4.4463e-04
# Epoch 47/60
# 6/6 [==============================] - 0s 12ms/step - loss: 4.4443e-04
# Epoch 48/60
# 6/6 [==============================] - 0s 13ms/step - loss: 4.5116e-04
# Epoch 49/60
# 6/6 [==============================] - 0s 12ms/step - loss: 4.9316e-04
# Epoch 50/60
# 6/6 [==============================] - 0s 13ms/step - loss: 4.2998e-04
# Epoch 51/60
# 6/6 [==============================] - 0s 13ms/step - loss: 4.5121e-04
# Epoch 52/60
# 6/6 [==============================] - 0s 12ms/step - loss: 4.9942e-04
# Epoch 53/60
# 6/6 [==============================] - 0s 12ms/step - loss: 4.5103e-04
# Epoch 54/60
# 6/6 [==============================] - 0s 12ms/step - loss: 4.7895e-04
# Epoch 55/60
# 6/6 [==============================] - 0s 13ms/step - loss: 4.5378e-04
# Epoch 56/60
# 6/6 [==============================] - 0s 12ms/step - loss: 4.3105e-04
# Epoch 57/60
# 6/6 [==============================] - 0s 12ms/step - loss: 4.4781e-04
# Epoch 58/60
# 6/6 [==============================] - 0s 13ms/step - loss: 4.4209e-04
# Epoch 59/60
# 6/6 [==============================] - 0s 13ms/step - loss: 4.2262e-04
# Epoch 60/60
# 6/6 [==============================] - 0s 12ms/step - loss: 4.0322e-04

# %%
plt.figure(figsize=(20,5))
plt.plot(history_twitter.history['loss'], label='Training loss')
plt.title('Training loss')
plt.legend()

# %%
training_dates= df.index[:X_train_lstm_without_twitter.shape[0]]
#Make prediction
training_prediction_without_twitter = cnn_lstm_model_without_twitter.predict(X_train_lstm_without_twitter)

training_prediction_twitter = cnn_lstm_model_twitter.predict(X_train_lstm_twitter)

training_prediction_without_twitter=training_prediction_without_twitter.reshape(training_prediction_without_twitter.shape[0], training_prediction_without_twitter.shape[2])

training_prediction_twitter=training_prediction_twitter.reshape(training_prediction_twitter.shape[0], training_prediction_twitter.shape[2])

y_train_pred_lstm_without_twitter = scaler_for_inference.inverse_transform(training_prediction_without_twitter)

y_train_pred_lstm_twitter = scaler_for_inference.inverse_transform(training_prediction_twitter)

y_train_lstm_reshaped_without_twitter=y_train_lstm_without_twitter.reshape(y_train_lstm_without_twitter.shape[0], y_train_lstm_without_twitter.shape[2])

y_train_actual_lstm = scaler_for_inference.inverse_transform(y_train_lstm_reshaped_without_twitter)
# Out:
# 12/12 [==============================] - 0s 6ms/step
# 12/12 [==============================] - 0s 8ms/step

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error
from math import sqrt

def plot_predictions_with_dates (type,twitter,dates,y_actual_lstm,y_pred_lstm):
    predicted_features=['şimdi']
    for i,predicted_feature in enumerate(predicted_features):
        plt.figure(figsize=(15,6))
        if twitter :
            plt.title(f'LSTM {type} prediction of {predicted_feature} feature After adding twitter sentiment analysis')
        else:
            plt.title(f'LSTM {type} prediction of {predicted_feature} feature without twitter sentiment analysis')
        sns.lineplot(x=dates, y=y_actual_lstm[:,i],label='Actual')
        sns.lineplot(x=dates, y=y_pred_lstm[:, i], label='Predicted')
        plt.show()
        error=mean_squared_error(y_actual_lstm[:,i], y_pred_lstm[:, i])
        print(f'Mean square error for {predicted_feature} ={error}')
    print('Total mean square error', mean_squared_error(y_actual_lstm, y_pred_lstm))

# %%
testing_dates= df.index[-X_test_lstm_without_twitter.shape[0]:]
#Make prediction
testing_prediction_without_twitter = cnn_lstm_model_without_twitter.predict(X_test_lstm_without_twitter)
testing_prediction_twitter = cnn_lstm_model_twitter.predict(X_test_lstm_twitter)

testing_prediction_without_twitter=testing_prediction_without_twitter.reshape(testing_prediction_without_twitter.shape[0], testing_prediction_without_twitter.shape[2])
testing_prediction_twitter=testing_prediction_twitter.reshape(testing_prediction_twitter.shape[0], testing_prediction_twitter.shape[2])

y_test_pred_lstm_without_twitter = scaler_for_inference.inverse_transform(testing_prediction_without_twitter)
y_test_pred_lstm_twitter = scaler_for_inference.inverse_transform(testing_prediction_twitter)

y_test_actual_lstm_reshaped_without_twitter=y_test_lstm_without_twitter.reshape(y_test_lstm_without_twitter.shape[0], y_test_lstm_without_twitter.shape[2])


y_test_actual_lstm = scaler_for_inference.inverse_transform(y_test_actual_lstm_reshaped_without_twitter)
# Out:
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 38ms/step

# %%
training_dates= df.index[:X_train_lstm_twitter.shape[0]]
plot_predictions_with_dates('Training',False,training_dates,y_train_actual_lstm ,y_train_pred_lstm_without_twitter)
# Out:
# Mean square error for şimdi =2553.3731670191437
# Total mean square error 2553.3731670191437

# %%
training_dates= df.index[:X_train_lstm_twitter.shape[0]]
plot_predictions_with_dates('Training',True,training_dates,y_train_actual_lstm ,y_train_pred_lstm_twitter)
# Out:
# Mean square error for şimdi =2066.4123145080357
# Total mean square error 2066.4123145080357

# %%
plot_predictions_with_dates('Testing',False,testing_dates,y_test_actual_lstm,y_test_pred_lstm_without_twitter)
# Out:
# Mean square error for şimdi =22410.16458722229
# Total mean square error 22410.16458722229

# %%
plot_predictions_with_dates('Testing',True,testing_dates,y_test_actual_lstm,y_test_pred_lstm_twitter)
# Out:
# Mean square error for şimdi =15672.002849803783
# Total mean square error 15672.002849803783

# %%
cnn_lstm_model_twitter.save('cnn_lstm_twitter.h5')

# %%
from pickle import dump
dump(scaler_for_inference, open('scaler.pkl', 'wb'))
